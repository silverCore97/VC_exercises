# %% [markdown]
# # Week 5: PCA
#
# **The exercise of this week is about PCA. First load the following libraries that will be necessary.**

# %%
# !pip install scipy
# !pip install scikit-image
# !pip install matplotlib
# Out:
# Requirement already satisfied: scipy in c:\users\aletain\appdata\local\programs\python\python38\lib\site-packages (1.6.3)
# Requirement already satisfied: numpy<1.23.0,>=1.16.5 in c:\users\aletain\appdata\local\programs\python\python38\lib\site-packages (from scipy) (1.18.5)
# Requirement already satisfied: scikit-image in c:\users\aletain\appdata\local\programs\python\python38\lib\site-packages (0.18.3)
# Requirement already satisfied: numpy>=1.16.5 in c:\users\aletain\appdata\local\programs\python\python38\lib\site-packages (from scikit-image) (1.18.5)
# Requirement already satisfied: matplotlib!=3.0.0,>=2.0.0 in c:\users\aletain\appdata\local\programs\python\python38\lib\site-packages (from scikit-image) (3.4.3)
# Requirement already satisfied: pillow!=7.1.0,!=7.1.1,>=4.3.0 in c:\users\aletain\appdata\local\programs\python\python38\lib\site-packages (from scikit-image) (8.3.1)
# Requirement already satisfied: PyWavelets>=1.1.1 in c:\users\aletain\appdata\local\programs\python\python38\lib\site-packages (from scikit-image) (1.1.1)
# Requirement already satisfied: tifffile>=2019.7.26 in c:\users\aletain\appdata\local\programs\python\python38\lib\site-packages (from scikit-image) (2021.8.30)
# Requirement already satisfied: scipy>=1.0.1 in c:\users\aletain\appdata\local\programs\python\python38\lib\site-packages (from scikit-image) (1.6.3)
# Requirement already satisfied: networkx>=2.0 in c:\users\aletain\appdata\local\programs\python\python38\lib\site-packages (from scikit-image) (2.5.1)
# Requirement already satisfied: imageio>=2.3.0 in c:\users\aletain\appdata\local\programs\python\python38\lib\site-packages (from scikit-image) (2.9.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\aletain\appdata\local\programs\python\python38\lib\site-packages (from matplotlib!=3.0.0,>=2.0.0->scikit-image) (2.8.1)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\aletain\appdata\local\programs\python\python38\lib\site-packages (from matplotlib!=3.0.0,>=2.0.0->scikit-image) (2.4.7)
# Requirement already satisfied: cycler>=0.10 in c:\users\aletain\appdata\local\programs\python\python38\lib\site-packages (from matplotlib!=3.0.0,>=2.0.0->scikit-image) (0.10.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\aletain\appdata\local\programs\python\python38\lib\site-packages (from matplotlib!=3.0.0,>=2.0.0->scikit-image) (1.3.2)
# Requirement already satisfied: decorator<5,>=4.3 in c:\users\aletain\appdata\local\programs\python\python38\lib\site-packages (from networkx>=2.0->scikit-image) (4.4.2)
# Requirement already satisfied: six in c:\users\aletain\appdata\local\programs\python\python38\lib\site-packages (from cycler>=0.10->matplotlib!=3.0.0,>=2.0.0->scikit-image) (1.16.0)
# Requirement already satisfied: matplotlib in c:\users\aletain\appdata\local\programs\python\python38\lib\site-packages (3.4.3)
# Requirement already satisfied: numpy>=1.16 in c:\users\aletain\appdata\local\programs\python\python38\lib\site-packages (from matplotlib) (1.18.5)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\aletain\appdata\local\programs\python\python38\lib\site-packages (from matplotlib) (1.3.2)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\aletain\appdata\local\programs\python\python38\lib\site-packages (from matplotlib) (2.4.7)
# Requirement already satisfied: cycler>=0.10 in c:\users\aletain\appdata\local\programs\python\python38\lib\site-packages (from matplotlib) (0.10.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\aletain\appdata\local\programs\python\python38\lib\site-packages (from matplotlib) (2.8.1)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\aletain\appdata\local\programs\python\python38\lib\site-packages (from matplotlib) (8.3.1)
# Requirement already satisfied: six in c:\users\aletain\appdata\local\programs\python\python38\lib\site-packages (from cycler>=0.10->matplotlib) (1.16.0)

# %%
# %matplotlib inline
from skimage.io import imread
from scipy import signal,ndimage
import numpy as np
import time
import scipy.io as sio
from matplotlib.pyplot import imshow,show,figure
import skimage.transform as tf
import IPython
import scipy
from sys import getsizeof

def make_grid(image_list,rows=5):
    cols = len(image_list)//rows
    row_image_list = []
    for c in range(cols):
        col_image_list = []
        for r in range(rows):
            col_image_list.append(image_list[c*rows+r])
        col_image = np.concatenate(col_image_list,axis=0)
        row_image_list.append(col_image)
    return np.concatenate(row_image_list,axis=1)

# %% [markdown]
# # Load images
#
# We use the AT&T dataset, which consists of 40 people with 10 experssions each. We split the dataset into two parts, training images and test images. The training images will be used to extract the eigenfaces, which are then used to compress test images.
#
# **First, we load the training data.** Here we take 5 expressions of 20 people as training set.

# %%
train_person_ids = np.arange(1,21)
train_expression_ids = np.arange(1,6)
train_image_list = []
for pid in train_person_ids:
    for eid in train_expression_ids:
        image = imread('dataset/s%d/%d.pgm'%(pid,eid))/255.
        image = tf.rescale(image,0.6)
        h,w = image.shape
        train_image_list.append(image)

train_image_collage = make_grid(train_image_list,rows=5)
imshow(train_image_collage,cmap='gray')

# %% [markdown]
# **Then we load the test images.** To see if the method can deal with unseen people and unseen expressions, we test with the rest 5 expressions of the rest 20 people.

# %%
test_person_ids = np.arange(21,38)
test_expression_ids = np.arange(6,11)
test_image_list = []
for pid in test_person_ids:
    for eid in test_expression_ids:
        image = imread('dataset/s%d/%d.pgm'%(pid,eid))/255.
        image = tf.rescale(image,0.6)
        h,w = image.shape
        test_image_list.append(image)
        
test_image_collage = make_grid(test_image_list,rows=5)
imshow(test_image_collage,cmap='gray')

# %% [markdown]
# ## Part A: Image Compression
#
# In part A, we will use PCA to compress face images. For convenience we reshape the N training images into vectors of length $D = Height\times Width$ and concatenate all vectors to form a $N \times D$ matrix $X$.

# %%
image_vectors = [image.flatten() for image in train_image_list]
X = np.stack(image_vectors,axis=1)

# %% [markdown]
# **Compute the mean and covariance of images.** The mean of images $\mu$ is a vector of length $D$ and can be visaulized as an image. The covariance $\Sigma$ is a $D \times D$ matrix. You can use `numpy.mean()` and `numpy.cov()` for the computation.

# %%
mean = np.mean(X,axis=1)
covariance = np.cov(X)
print(covariance.shape)
imshow(mean.reshape(h,w),cmap='gray')
# Out:
# (3685, 3685)

# %% [markdown]
# **Compute eigenfaces.** Eigenfaces are the eigenvectors correponding to k-largest eigenvalues of covariance matrix. You can use `scipy.sparse.linalg.eigs(mat,k)` to compute $k$ largest eigenvalues of $mat$ and corresponding eigenvectors $[v_1...v_k]$ . Note that this function returns complex valued results, which needs to be converted to real numbers using `numpy.real()`.

# %%
print('H')
num_eigenvectors = 50
eigenvalues,eigenvectors = scipy.sparse.linalg.eigs(covariance,num_eigenvectors)
eigenvectors=np.real(eigenvectors)                 

                       
'''
for eigenvector in eigenvectors.T:
    imshow(eigenvector.reshape(h,w),cmap='gray')    
    IPython.display.clear_output(True)
    show()'''
    
print(eigenvectors.shape)

# %% [markdown]
# **Now we can use the computed eigenfaces to compress images.** Face images can be approximated by linear combinations of eigenfaces $x=\mu + \alpha_1v_1 + \alpha_2v_2 + .... + \alpha_kv_k$. Therefore, we can use the weights $[\alpha_1 ... \alpha_k]$ to record a image, instead of saving all pixels values. Each weight $\alpha_i$ is the projection of the normalized image $\tilde{x} = x-\mu$ onto the corresponding eigenface $v_i$, which can be computed by dot product $\alpha_i = \tilde{x} \cdot v_i$.
#
# To recover a image from its compression we can use  $x=\mu + \alpha_1v_1 + \alpha_2v_2 + .... + \alpha_kv_k$.
#
#
# **Complete the lines below to compress a image into a $k$ dimensional vector.**
#
# **Q:** Compress training images and test images. On which set the method works better? Why?
#
# **Q:** Compress image with different number of eigenfaces. What's the influence of $k$?
#
# **Q:** Considering that we want to reduce data size, what is the maximum value of $k$?

# %%
error_images = []
for image in train_image_list[:]:
    
    var_image = image.flatten()-mean #subtract the average face. Flatten picture for correct shape
   # print(var_image.shape)
    #matrix multiplication with numpy.dot() for projection
    
    # Your lines here. Compress the image into a vector of lenght k.
    compressed_image = np.dot(var_image,eigenvectors)
    #print(compressed_image.shape)   size(50,) for 50 eigenvector weights
    
    decompressed_image = mean+np.dot(eigenvectors,compressed_image)
    
    error_image = np.abs(decompressed_image-image.flatten())
    error_images.append(error_image)

    imshow(np.concatenate([image.reshape(h,w),\
                          decompressed_image.reshape(h,w),\
                          error_image.reshape(h,w)],axis=-1),cmap='gray')

    IPython.display.clear_output(True)
    show()
    
print('Size before compression: %d Bytes'%image.nbytes)
print('Size after compression: %d Bytes'%compressed_image.nbytes)
           
error_images = np.stack(error_images,0)
ssd_error = (error_images**2).sum(-1).mean()
print(ssd_error)
# Out:
# Size before compression: 29480 Bytes
# Size after compression: 400 Bytes
# 4.9486008212200225

# %% [markdown]
# **Q:** Compress training images and test images. On which set the method works better? Why?

# %%
error_images = []
for image in test_image_list[:]:    
    var_image = image.flatten()-mean 
    compressed_image = np.dot(var_image,eigenvectors)
    decompressed_image = mean+np.dot(eigenvectors,compressed_image)
    error_image = np.abs(decompressed_image-image.flatten())
    error_images.append(error_image)
    imshow(np.concatenate([image.reshape(h,w),\
                          decompressed_image.reshape(h,w),\
                          error_image.reshape(h,w)],axis=-1),cmap='gray')
    IPython.display.clear_output(True)
    show()
    
print('Size before compression: %d Bytes'%image.nbytes)
print('Size after compression: %d Bytes'%compressed_image.nbytes)
           
error_images = np.stack(error_images,0)
ssd_error = (error_images**2).sum(-1).mean()
print(ssd_error)
# Clearly the method works better on the training sample as the faces of the test set were not used when 
# creating the eigenfaces
# Out:
# Size before compression: 29480 Bytes
# Size after compression: 400 Bytes
# 32.959482315210835

# %% [markdown]
# **Q:** Compress image with different number of eigenfaces. What's the influence of $k$?

# %%
num_eigenvectors = 100
eigenvalues,eigenvectors = scipy.sparse.linalg.eigs(covariance,num_eigenvectors)
eigenvectors=np.real(eigenvectors)

# %%
error_images = []

vector_list=np.array([10,20,50,100])
for image in train_image_list[:]:
    
    var_image = image.flatten()-mean #subtract the average face. Flatten picture for correct shape
   # print(var_image.shape)
    #matrix multiplication with numpy.dot() for projection
    n=0
    compressed_image=[]
    decompressed_image=[]
    error_image2=[]
    for v in vector_list:        

        # Your lines here. Compress the image into a vector of lenght k.
        compressed_image.append( np.dot(var_image,(np.array(eigenvectors))[:,0:v]))
        #print(compressed_image.shape)   size(50,) for 50 eigenvector weights

        decompressed_image.append(  mean+np.dot(eigenvectors[:,0:v],compressed_image[n]))

        error_image = np.abs(decompressed_image[n]-image.flatten())
        error_images.append(error_image[n])
        error_image2.append(error_image)
        n+=1
    print('Size before compression: %d Bytes'%image.nbytes)
    print('Size after compression with 10 weights: %d Bytes'%compressed_image[0].nbytes)
    print('Size after compression with 20 weights: %d Bytes'%compressed_image[1].nbytes)
    print('Size after compression with 50 weights: %d Bytes'%compressed_image[2].nbytes)
    print('Size after compression with 100 weights: %d Bytes'%compressed_image[3].nbytes)
    imshow(np.concatenate([image.reshape(h,w),\
                          decompressed_image[0].reshape(h,w),\
                          error_image2[0].reshape(h,w),\
                          decompressed_image[1].reshape(h,w),\
                          error_image2[1].reshape(h,w),\
                          decompressed_image[2].reshape(h,w),\
                          error_image2[2].reshape(h,w),\
                          decompressed_image[3].reshape(h,w),\
                          error_image2[3].reshape(h,w)],axis=-1),cmap='gray',)

    IPython.display.clear_output(True)
    show()

# %% [markdown]
# **Q:** Considering that we want to reduce data size, what is the maximum value of $k$?

# %% [markdown]
# 8 Bytes per weight
#
# 29480/8= **3685** is the maximum value of **k**

# %% [markdown]
# # Part B: Face Detection with PCA
# **In this part we will use PCA to detect faces.** In previous part, we have implemented a compressor for face images. Since the eigenvectors are extracted from faces images, we can expect that such a compressor would fail on other images, leading to erroneous decompression. This fact can be used for face detection.
#
# You are given an image with a face and your task is to find the location (x coordinate) of the face.
# Try to compress and then decompress each part of the image using the method in part A, and then compute the SSD error. Based on the SSD error, find the localtion (x coordinate) where the face is located.

# %%
import matplotlib.pyplot as plt
import matplotlib.patches as patches

image_vectors = [image.flatten() for image in train_image_list]
X = np.stack(image_vectors,axis=1)
mean = np.mean(X,axis=1)
covariance = np.cov(X)

num_eigenvectors = 50
eigenvalues,eigenvectors = scipy.sparse.linalg.eigs(covariance,num_eigenvectors)
eigenvectors=np.real(eigenvectors)    

image = imread('FaceDetection.bmp')[:h,:]/255.
h_,w_ = image.shape

errors = []

# iterate over each part of the image
for x in range(w_-w):
    image_crop = image[:,x:x+w].flatten()
    im=image_crop.flatten()-mean
    compressed_image = np.dot(im,eigenvectors)
    decompressed_image = mean+np.dot(compressed_image,eigenvectors.T)
    error_image = np.abs(decompressed_image-im.flatten())
    
    error =np.sum(error_image)
    # Your lines here. Compress and decompress the image patch and compute the reconstruction error.
    
    errors.append(error)
    
    fig, ax = plt.subplots(2,1)
    rect = patches.Rectangle((x,0),w,h,linewidth=3,edgecolor='r',facecolor='none')
    ax[0].imshow(image,cmap='gray')
    ax[0].add_patch(rect)
    ax[1].plot(np.arange(x+1)+w//2,np.array(errors))
    ax[1].set_xlim([0,w_])
    IPython.display.clear_output(True)
    show()

x_best = np.argmin(errors)
fig, ax = plt.subplots(2,1)
rect = patches.Rectangle((x_best,0),w,h,linewidth=3,edgecolor='g',facecolor='none')

ax[0].imshow(image,cmap='gray')
ax[0].add_patch(rect)
ax[1].plot(np.arange(x+1)+w//2,np.array(errors))
ax[1].set_xlim([0,w_])
IPython.display.clear_output(True)
show()
